# %% [markdown]
# <a href="https://colab.research.google.com/github/kebscharry/CharityMomanyi/blob/main/EDA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.graphics.mosaicplot as mosaic

# %%
# load datasets
data = pd.read_csv('/content/nhanes_reduced .csv')
age_directChol = df[['Age', 'DirectChol']]

# %%
# filter data for ages greater than 40
filtered_data = df[df['Age']>40]

# %%
# adding titles and labels
#scatter plot using filtered data
plt.scatter(filtered_data['Age'], filtered_data['DirectChol'], color='orange')
plt.title('Age vs. DirectChol Level (Ages > 40)')
plt.xlabel('Age (years)')
plt.ylabel('DirectChol level (mg/dl)')
plt.show()

# %%
age_directChol = df[['BMI', 'PhysActiveDays']]
# filter data for ages greater than 40
filtered_data = df[df['BMI']>40]

# %%
# adding titles and labels
#scatter plot using filtered data
plt.scatter(filtered_data['BMI'], filtered_data['PhysActiveDays'], color='orange')
plt.title('Age vs. PhysActiveDays Level ')
plt.xlabel('BMI (years)')
plt.ylabel('PhysActiveDays (mg/dl)')
plt.show()

# %%
60-23
# Out:
# 37

# %%
37/5
# Out:
# 7.4

# %%
28+8
# Out:
# 36

# %%
# Convert the 'Work' column to categorical type if it isn't already
data['Work'] = data['Work'].astype('category')

work_categories = data['Work'].cat.categories
fig, axes = plt.subplots(nrows=len(work_categories),
                         ncols=1, figsize=(10, 15), sharex=True)

# %%
# work_categories = data['Work'].cat.categories
# fig, axes = plt.subplots(nrows=len(work_categories),
# ncols = 1, figsize=(10, 15), sharex=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-eea12144b7f3> in <cell line: 1>()
# ----> 1 work_categories = data['Work'].cat.categories
#       2 fig, axes = plt.subplots(nrows=len(work_categories),
#       3 ncols = 1, figsize=(10, 15), sharex=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
# ...

# %%
# for ax, category in zip(axes, work_categories):
#   sns.histplot(data[data['Work'] == category]['BMI']', bins=20, ax=ax)
#   ax.set_title(f'BMI Distribution for Work Category: {category}')
#   plt.tight_layout()
#   plt.show()
# Out:
#   File "<ipython-input-19-a82ba2b3bdea>", line 2
#     sns.histplot(data[data['Work'] == category]['BMI']', bins=20, ax=ax)
#                                                       ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sns.boxplot(x='HHIncome', y='BMI', data=data)
plt.title('Boxplots of HHIncome by BMI')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Gender', y='BMI', data=data)
plt.title('Boxplots of Gender by BMI')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Gender', y='DirectChol', data=data)
plt.title('Boxplots of Gender by DirectChol')
plt.xticks(rotation=90)
plt.show()

# %%
# density plot
plt.figure(figsize=(12, 8))
sns.kdeplot(data=data, x='BMI', hue='Work', multiple='stack')
plt.title('KDE Plot of BMI by work Type')
plt.xlabel('BMI')
plt.ylabel('Density')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = data['BMI']
log_df = np.log(df)

# %%
plt.figure(figsize=(10, 6))
plt.plot(df, label='Original Data', marker='o', linestyle='-', color='blue')
plt.plot(log_df, label='Log Transformed Data', marker='o', linestyle='-', color='red')
plt.title('Original vs log Transformation Data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %%
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.show()
