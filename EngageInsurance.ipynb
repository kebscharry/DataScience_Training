# %% [markdown]
# <a href="https://colab.research.google.com/github/kebscharry/CharityMomanyi/blob/main/EngageInsurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../content/insurance.csv')
df.head()
# Out:
#     ID  age     sex     bmi  children smoker     region      charges
# 0  1.0   19  female  27.900         0    yes  southwest  16884.92400
# 1  1.0   18    male     NaN         1     no  southeast   1725.55230
# 2  3.0   28    male  33.000         3     no  southeast   4449.46200
# 3  4.0   33    male  22.705         0     no  northwest  21984.47061
# 4  4.0   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 8)

# %%
df.describe()
# Out:
#                 ID          age          bmi     children       charges
# count  1332.000000  1338.000000  1337.000000  1338.000000   1338.000000
# mean    666.498498    39.207025    30.661073     1.094918  13270.422265
# std     384.662182    14.049960     6.099876     1.205493  12110.011237
# min       1.000000    18.000000    15.960000     0.000000   1121.873900
# 25%     333.750000    27.000000    26.290000     0.000000   4740.287150
# 50%     666.500000    39.000000    30.400000     1.000000   9382.033000
# 75%     999.250000    51.000000    34.700000     2.000000  16639.912515
# max    1332.000000    64.000000    53.130000     5.000000  63770.428010

# %%
df.dtypes
# Out:
# ID          float64
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ID          0
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# replacing missing values in BMI
# column with mean of that column
df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
print(df)
# Out:
#        ID  age     sex        bmi  children smoker     region      charges
# 0     1.0   19  female  27.900000         0    yes  southwest  16884.92400
# 1     1.0   18    male  30.661073         1     no  southeast   1725.55230
# 2     3.0   28    male  33.000000         3     no  southeast   4449.46200
# 3     4.0   33    male  22.705000         0     no  northwest  21984.47061
# 4     4.0   32    male  28.880000         0     no  northwest   3866.85520
# ...   ...  ...     ...        ...       ...    ...        ...          ...
# 1333  NaN   50    male  30.970000         3     no  northwest  10600.54830
# 1334  NaN   18  female  31.920000         0     no  northeast   2205.98080
# 1335  NaN   18  female  36.850000         0     no  southeast   1629.83350
# 1336  NaN   21  female  25.800000         0     no  southwest   2007.94500
# 1337  NaN   61  female  29.070000         0    yes  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %%
#replacing values
df.replace(to_replace="southeast",
           value="Nairobi")
# Out:
#           ID  age  sex     bmi  children smoker     region      charges
# 159    160.0   50  1.0  27.830         3     no    Nairobi  19749.38338
# 254    255.0   50  0.0  31.825         0    yes  northeast  41097.16175
# 271    272.0   50  0.0  34.200         2    yes  southwest  42856.83800
# 273    274.0   50  0.0  27.455         1     no  northeast   9617.66245
# 310    311.0   50  0.0  26.600         0     no  southwest   8444.47400
# 316    317.0   50  0.0  32.205         0     no  northwest   8835.26495
# 338    339.0   50  0.0  32.300         1    yes  northeast  41919.09700
# 351    352.0   50  1.0  25.600         0     no  southwest   8932.08400
# 387    388.0   50  0.0  25.365         2     no  northwest  30284.64294
# 520    521.0   50  1.0  27.360         0     no  northeast  25656.57526
# 563    564.0   50  0.0  44.770         1     no    Nairobi   9058.73030
# 701    702.0   50  1.0  44.745         0     no  northeast   9541.69555
# 711    712.0   50  1.0  23.540         2     no    Nairobi  10107.22060
# 724    725.0   50  1.0  27.075         1     no  northeast  10106.13425
# 744    745.0   50  0.0  26.410         0     no  northwest   8827.20990
# 745    746.0   50  1.0  30.115         1     no  northwest   9910.35985
# 783    784.0   50  1.0  27.600         1    yes  southwest  24520.26400
# 870    871.0   50  0.0  36.200         0     no  southwest   8457.81800
# 925    926.0   50  0.0  32.110         2     no  northeast  25333.33284
# 941    942.0   50  1.0  46.090         1     no    Nairobi   9549.56510
# 970    971.0   50  1.0  28.160         3     no    Nairobi  10702.64240
# 992    993.0   50  1.0  31.600         2     no  southwest  10118.42400
# 1094  1095.0   50  1.0  33.700         4     no  southwest  11299.34300
# 1107  1108.0   50  1.0  26.220         2     no  northwest  10493.94580
# 1135  1136.0   50  1.0  28.120         3     no  northwest  11085.58680
# 1140  1141.0   50  0.0  37.070         1     no    Nairobi   9048.02730
# 1144  1145.0   50  0.0  32.300         2     no  southwest   9630.39700
# 1222  1223.0   50  0.0  25.300         0     no    Nairobi   8442.66700

# %%
df.replace(to_replace=["Southwest", "northwest"],
           value="engage")
# Out:
#           ID  age     sex     bmi  children smoker     region      charges
# 2        3.0   28    male  33.000         3     no  southeast   4449.46200
# 5        6.0   31  female  25.740         0     no  southeast   3756.62160
# 6        7.0   46  female  33.440         1     no  southeast   8240.58960
# 7        8.0   37  female  27.740         3     no     engage   7281.50560
# 8        9.0   37    male  29.830         2     no  northeast   6406.41070
# ...      ...  ...     ...     ...       ...    ...        ...          ...
# 1327  1328.0   51    male  30.030         1     no  southeast   9377.90470
# 1328  1329.0   23  female  24.225         2     no  northeast  22395.74424
# 1329  1330.0   52    male  38.600         2     no  southwest  10325.20600
# 1330  1331.0   57  female  25.740         2     no  southeast  12629.16560
# 1331  1332.0   23  female  33.400         0     no  southwest  10795.93733
#
# [1328 rows x 8 columns]

# %%
#REMOVE DUPLICATES
# sorting by ID
df.sort_values("ID", inplace=True)

# dropping ALL duplicate values
df.drop_duplicates(subset="ID",
                     keep=False, inplace=True)

# displaying data
df
# Out:
#           ID  age     sex     bmi  children smoker     region      charges
# 2        3.0   28    male  33.000         3     no  southeast   4449.46200
# 5        6.0   31  female  25.740         0     no  southeast   3756.62160
# 6        7.0   46  female  33.440         1     no  southeast   8240.58960
# 7        8.0   37  female  27.740         3     no  northwest   7281.50560
# 8        9.0   37    male  29.830         2     no  northeast   6406.41070
# ...      ...  ...     ...     ...       ...    ...        ...          ...
# 1327  1328.0   51    male  30.030         1     no  southeast   9377.90470
# 1328  1329.0   23  female  24.225         2     no  northeast  22395.74424
# 1329  1330.0   52    male  38.600         2     no  southwest  10325.20600
# 1330  1331.0   57  female  25.740         2     no  southeast  12629.16560
# 1331  1332.0   23  female  33.400         0     no  southwest  10795.93733
#
# [1328 rows x 8 columns]

# %%
# Filter age above 50
df = df[df['age'] >= 50].copy()


# Display data
df
# Out:
#           ID  age     sex     bmi  children smoker     region      charges
# 9       10.0   60  female  25.840         0     no  northwest  28923.13692
# 11      12.0   62  female  26.290         0    yes  southeast  27808.72510
# 13      14.0   56  female  39.820         0     no  southeast  11090.71780
# 16      17.0   52  female  30.780         1     no  northeast  10797.33620
# 18      19.0   56    male  40.300         0     no  southwest  10602.38500
# ...      ...  ...     ...     ...       ...    ...        ...          ...
# 1322  1323.0   62    male  38.830         0     no  southeast  12981.34570
# 1325  1326.0   61    male  33.535         0     no  northeast  13143.33665
# 1327  1328.0   51    male  30.030         1     no  southeast   9377.90470
# 1329  1330.0   52    male  38.600         2     no  southwest  10325.20600
# 1330  1331.0   57  female  25.740         2     no  southeast  12629.16560
#
# [382 rows x 8 columns]

# %%
# Filter age=50
df = df[df['age']== 50].copy()


# Display data
df
# Out:
#           ID  age     sex     bmi  children smoker     region      charges
# 159    160.0   50  female  27.830         3     no  southeast  19749.38338
# 254    255.0   50    male  31.825         0    yes  northeast  41097.16175
# 271    272.0   50    male  34.200         2    yes  southwest  42856.83800
# 273    274.0   50    male  27.455         1     no  northeast   9617.66245
# 310    311.0   50    male  26.600         0     no  southwest   8444.47400
# 316    317.0   50    male  32.205         0     no  northwest   8835.26495
# 338    339.0   50    male  32.300         1    yes  northeast  41919.09700
# 351    352.0   50  female  25.600         0     no  southwest   8932.08400
# 387    388.0   50    male  25.365         2     no  northwest  30284.64294
# 520    521.0   50  female  27.360         0     no  northeast  25656.57526
# 563    564.0   50    male  44.770         1     no  southeast   9058.73030
# 701    702.0   50  female  44.745         0     no  northeast   9541.69555
# 711    712.0   50  female  23.540         2     no  southeast  10107.22060
# 724    725.0   50  female  27.075         1     no  northeast  10106.13425
# 744    745.0   50    male  26.410         0     no  northwest   8827.20990
# 745    746.0   50  female  30.115         1     no  northwest   9910.35985
# 783    784.0   50  female  27.600         1    yes  southwest  24520.26400
# 870    871.0   50    male  36.200         0     no  southwest   8457.81800
# 925    926.0   50    male  32.110         2     no  northeast  25333.33284
# 941    942.0   50  female  46.090         1     no  southeast   9549.56510
# 970    971.0   50  female  28.160         3     no  southeast  10702.64240
# 992    993.0   50  female  31.600         2     no  southwest  10118.42400
# 1094  1095.0   50  female  33.700         4     no  southwest  11299.34300
# 1107  1108.0   50  female  26.220         2     no  northwest  10493.94580
# 1135  1136.0   50  female  28.120         3     no  northwest  11085.58680
# 1140  1141.0   50    male  37.070         1     no  southeast   9048.02730
# 1144  1145.0   50    male  32.300         2     no  southwest   9630.39700
# 1222  1223.0   50    male  25.300         0     no  southeast   8442.66700

# %%
# Categorize gender
df['sex'] = df['sex'].map({'male': 0,
                                 'female': 1, }).astype(float)
df
# Out:
#           ID  age  sex     bmi  children smoker     region      charges
# 159    160.0   50  1.0  27.830         3     no  southeast  19749.38338
# 254    255.0   50  0.0  31.825         0    yes  northeast  41097.16175
# 271    272.0   50  0.0  34.200         2    yes  southwest  42856.83800
# 273    274.0   50  0.0  27.455         1     no  northeast   9617.66245
# 310    311.0   50  0.0  26.600         0     no  southwest   8444.47400
# 316    317.0   50  0.0  32.205         0     no  northwest   8835.26495
# 338    339.0   50  0.0  32.300         1    yes  northeast  41919.09700
# 351    352.0   50  1.0  25.600         0     no  southwest   8932.08400
# 387    388.0   50  0.0  25.365         2     no  northwest  30284.64294
# 520    521.0   50  1.0  27.360         0     no  northeast  25656.57526
# 563    564.0   50  0.0  44.770         1     no  southeast   9058.73030
# 701    702.0   50  1.0  44.745         0     no  northeast   9541.69555
# 711    712.0   50  1.0  23.540         2     no  southeast  10107.22060
# 724    725.0   50  1.0  27.075         1     no  northeast  10106.13425
# 744    745.0   50  0.0  26.410         0     no  northwest   8827.20990
# 745    746.0   50  1.0  30.115         1     no  northwest   9910.35985
# 783    784.0   50  1.0  27.600         1    yes  southwest  24520.26400
# 870    871.0   50  0.0  36.200         0     no  southwest   8457.81800
# 925    926.0   50  0.0  32.110         2     no  northeast  25333.33284
# 941    942.0   50  1.0  46.090         1     no  southeast   9549.56510
# 970    971.0   50  1.0  28.160         3     no  southeast  10702.64240
# 992    993.0   50  1.0  31.600         2     no  southwest  10118.42400
# 1094  1095.0   50  1.0  33.700         4     no  southwest  11299.34300
# 1107  1108.0   50  1.0  26.220         2     no  northwest  10493.94580
# 1135  1136.0   50  1.0  28.120         3     no  northwest  11085.58680
# 1140  1141.0   50  0.0  37.070         1     no  southeast   9048.02730
# 1144  1145.0   50  0.0  32.300         2     no  southwest   9630.39700
# 1222  1223.0   50  0.0  25.300         0     no  southeast   8442.66700

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df['charges'], kde = True, color = 'c')
plt.title('Distribution of Charges')
# Out:
# Text(0.5, 1.0, 'Distribution of Charges')

# %% [markdown]
# This distribution is right-skewed. To make it closer to normal we can apply natural log

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.distplot(np.log10(df['charges']), kde = True, color = 'r' )

# %%
charges = df['charges'].groupby(df.region).sum().sort_values(ascending = True)
f, ax = plt.subplots(1, 1, figsize=(8, 6))
# Pass data as first argument, then specify x and y using keywords
ax = sns.barplot(x=charges.head().index, y=charges.head(), palette='Blues')

# %%
f, ax = plt.subplots(1,1, figsize=(12,8))
ax = sns.barplot(x = 'region', y = 'charges',
                 hue='smoker', data=df, palette='Reds_r')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='children', data=df, palette='Set1')

# %% [markdown]
# As we can see from these barplots the highest charges due to smoking are still in the Southeast but the lowest are in the Northeast. People in the Southwest generally smoke more than people in the Northeast, but people in the Northeast have higher charges by gender than in the Southwest and Northwest overall. And people with children tend to have higher medical costs overall as well

# %% [markdown]
# Now let's analyze the medical charges by age, bmi and children according to the smoking factor

# %%
ax = sns.lmplot(x = 'age', y = 'charges', data=df, hue='smoker', palette='Set1')
ax = sns.lmplot(x = 'bmi', y = 'charges', data=df, hue='smoker', palette='Set2')
ax = sns.lmplot(x = 'children', y = 'charges', data=df, hue='smoker', palette='Set3')

# %% [markdown]
# Smoking has the highest impact on medical costs, even though the costs are growing with age, bmi and children. Also people who have children generally smoke less, which the following violinplots shows too

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.violinplot(x = 'children', y = 'charges', data=df,
                 orient='v', hue='smoker', palette='inferno')
